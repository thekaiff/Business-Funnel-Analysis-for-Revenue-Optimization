# %% [markdown]
# # **1. Funnel Coversion Rates:**

# %% [markdown]
# ### **1-A. 🧠 How to explain this `overall conversion rate from MQLs to closed data` in interviews:**
#
# “To calculate the overall funnel conversion, I compared how many leads entered the funnel (from `mql_clean`) with how many ended as closed deals (from `cld_clean`). I computed the percentage and visualized it using a pie chart. The result was a 10.39% conversion rate, meaning approximately 1 in 10 leads actually converts. This metric acts as a baseline for evaluating the effectiveness of marketing channels, lead quality, and sales performance.”

# %% [markdown]
# ### **1-B. 🧠 How to explain this `conversion rate vary by marketing channel (origin)?` in an interview**
#
# “To understand conversion across marketing channels, I merged the closed-deals dataset with the MQL dataset using `mql_id`. This allowed me to identify which channels produced actual conversions. I then calculated conversion rate per channel by dividing converted leads by total leads for each origin.
#
# The results showed that paid search (12.17%) and organic search (11.54%) had the highest conversion rates, meaning these channels bring the most qualified leads. In contrast, email and display had much lower conversion rates. I visualized the results using a bar chart to clearly compare channel performance.”

# %% [markdown]
# ### **1-C. 🧠 How to explain this `How does conversion rate differ across business_segment or lead_type?` in an interview**
#
# “To compare conversion performance across business segments and lead types, I plotted the number of closed deals from the cleaned CLD dataset. Using countplots, I visualized which categories produce the most converted customers.
#
# The results showed strong conversions in home-related and lifestyle segments like home décor, health & beauty, and home appliances. For lead types, online_medium and online_big showed the highest conversions, indicating that more mature online sellers convert better. This analysis helps the business prioritize higher-performing segments and optimize lead nurturing for lower-performing ones.”
#
# **📌 What would happen if we changed the code?**
#
# ✔ If we grouped instead of counted
#
# You would get 0–1 KPIs instead of count values, changing interpretation.

# %% [markdown]
# ---

# %% [markdown]
# ## **2. Time-Based Metrics**
#
# ### **2-A. How to explain `average time taken to close a deal`?**
#
# “To understand how long it typically takes for a lead to convert, I merged the MQL table with the Closed Deals table using `mql_id`. Then I calculated the number of days between first contact and won date, and found the average closing time. The result was around **48.5 days.**
#
# The distribution shows that most deals close quickly—within 0–30 days—but there’s a long tail of deals that take several months, which pushes the average higher. The data is right-skewed, meaning a few slow deals heavily impact the average. This insight helps identify bottlenecks and evaluate sales team performance.”
#
#
# **🔄 What if you changed something?**
#
# ✔️ If you remove outliers
# - Average might drop from **48 days** → maybe around **20–30** days.
# Good to mention:
# “Outliers heavily affect the average because the data is right-skewed.”
#
# ✔️ If you group by segments (industry/lead type/SDR)
# You can understand:
# - which teams close deals faster
# - which customers respond faster
# - where bottlenecks exist
#
# ✔️ If you use median instead of mean
# - Median would give a more realistic central value because it is not affected by extreme values.

# %% [markdown]
# ### **2-B. How to explain `How does conversion velocity vary by time-to-close segments?`?**
#
# “To analyze conversion velocity, I grouped deals into time-to-close segments like 0–7 days, 8–15 days, and so on. Then I counted how many deals fall into each group and plotted the results.
#
# The key insight is that conversion is fastest early—about 30% of deals close in the first week. After 15 days the conversion rate drops sharply, but interestingly, 23% of deals still close after 60+ days, showing a long-tail sales cycle.
#
# This helps teams prioritize fast-moving leads while still maintaining a strategy for long-cycle customers.”

# %% [markdown]
# ---

# %% [markdown]
# # **3. Sales team Performance**

# %% [markdown]
# ### **How to explain `Which SDRs and SRs have the highest conversion rates?`?**
#
# “This analysis helps identify high-performing sales reps and any uneven distribution of workload or skill.”
# “If only a handful of SDRs/SRs drive most conversions, it may indicate:
# - Better training practices by the top performers
# - Uneven lead allocation
# - Or that certain reps need support or coaching.”
#
# “The company can use this insight for:
# - Performance reviews
# - Training programs
# - Fair lead distribution
# - Incentive planning
# - Improving forecast accuracy”

# %% [markdown]
# ---

# %% [markdown]
# # **4. Landing Page Optimization:**

# %% [markdown]
# ### **How to Explain `which landing pages (landing_page_id) or origin-landing page combinations drive the most conversions?`**
#
# Concatinated `origin` and `landing_page_id` columns and displayed Top 10 using barplot
#
# **📌 Business interpretation**
#
# - The company should prioritize the best-performing landing pages, optimize them further, and increase campaigns driving to those pages.
# - Underperforming combinations should be reviewed for messaging or UX problems.

# %% [markdown]
# ---

# %% [markdown]
# # **5. Behavioural Insights:**

# %% [markdown]
# ### **`specific lead_behaviour_profile convert more?`**
#
# “In the behavioral insight step, I analyzed the lead_behaviour_profile column to identify which profiles convert the most. I used value_counts() to get the closed-deals distribution and visualized it using a Seaborn bar chart. The results showed that ‘cat’ leads convert significantly higher than other types, followed by eagle and wolf, while shark has the lowest conversions. This insight helps in prioritizing high-value lead profiles and tailoring marketing or sales strategies.”

# %% [markdown]
# ---

# %% [markdown]
# # **6. Order Metrics:**
#
# ### **1. `average delivery time from purchase to customer?`**
#
# “To calculate delivery performance, I filtered only the delivered orders and computed the difference between the delivery date and purchase timestamp in days. Then I computed the average delivery time and visualized the distribution using a histogram. The results show the average delivery time is around 12 days, with most deliveries falling in the 10–15 day range, which helps assess the overall efficiency of the logistics process.”

# %% [markdown]
# ### **2.`How long do orders spend in each stage (purchase -> approval -> carrier -> delivery)?`**
#
# To measure how long orders spent in each stage, I calculated the time differences between key timestamps such as purchase time, approval time, carrier pickup time, and final delivery. I stored these durations in a dataframe and visualized them using a boxplot to understand the distribution and outliers.
# The analysis showed that the purchase-to-approval stage is very fast with almost no delays, while the approval-to-carrier stage has moderate variability. The carrier-to-delivery stage shows the highest delays and extreme outliers, indicating that most bottlenecks occur in the logistics and delivery process.

# %% [markdown]
# ### **3. What is the distribution of order statuses (e.g: canceled, delivered)?**
#
# “To understand how orders progress through the system, I analyzed the distribution of order statuses. Using value_counts(normalize=True) allowed me to convert the distribution into percentages. The results showed that almost 99% of orders are successfully delivered, about 1% are still shipped, and less than 0.1% are canceled. This indicates a very healthy fulfillment process with low cancellation risk and high delivery reliability, which is a strong operational strength.”

# %% [markdown]
# ---

# %% [markdown]
# # **7. Customer Retention:**
#
# ### **7-1. `What percentage of customers make repeat purchases?`**
# “To understand customer retention, I calculated how many orders each customer placed by grouping the dataset on customer_id. Then I identified repeat buyers by filtering customers with more than one order. The repeat purchase rate turned out to be 0%, meaning no customer made more than one purchase in this dataset. This suggests low customer retention or that the business model is oriented toward one-time purchases. This insight helps highlight areas where loyalty-building strategies or customer experience improvements can have a major impact.”

# %% [markdown]
# ---

# %% [markdown]
# # **8. Full Funnel Analysis:**
#
# ### **8-A. `What percentage of closed deals are followed by at least one delivered order?`**

# %% [markdown]
# “While performing full funnel analysis, I noticed that closed deals and orders had no direct join key. Instead of forcing an incorrect merge, I validated the data model and used a proxy-based funnel approach. This allowed me to evaluate how many closed deals led to successful delivery outcomes without inflating conversion metrics.”
#
# “The proxy full funnel analysis resulted in a 100% delivery success rate because the number of delivered orders far exceeds the number of closed deals. However, since there is no direct join key between sales and order data, this represents an upper bound rather than a true one-to-one conversion. In a real-world scenario, I would validate this using a deal-to-order mapping or customer-level linkage.”

# %% [markdown]
# ### **8-B. `Do faster overall delivery times correlate with better seller onboarding outcomes?`**
#
# directional insight, not causal proof.
#
# “Due to the absence of a direct seller-to-order mapping, seller-wise delivery speed could not be measured directly. Instead, I validated the data model and performed a proxy analysis using overall delivery speed as a platform-level indicator. The results show that delivery performance is strong, with most orders delivered within 15 days, indicating that logistics is unlikely to be a bottleneck affecting seller conversion. In a production environment, I would validate this using order_items data to link sellers to deliveries.”

# %% [markdown]
# ---

# %% [markdown]
# # **9. Bottleneck Identification:**
#
# ### **`Which order stage (approval, carrier handover, etc.) has the highest variabilty in time?`**

# %% [markdown]
# “To identify bottlenecks, I calculated the time spent in each order stage and measured variability using standard deviation. The carrier-to-delivery stage showed the highest variability, indicating that last-mile delivery is the most inconsistent part of the process. This suggests logistics partners and regional delivery conditions are the primary bottleneck rather than internal approval or handover processes.”
